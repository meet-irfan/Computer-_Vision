# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
image = cv2.imread('/content/narejo.jpeg', cv2.IMREAD_GRAYSCALE)

# Low-pass filter kernel (blurring)
blur_kernel = np.ones((5, 5), np.float32) / 25
blurred = cv2.filter2D(image, -1, blur_kernel)

# High-pass filter kernel (edge detection)
edge_kernel = np.array([[-1, -1, -1],
                        [-1,  8, -1],
                        [-1, -1, -1]])
edges = cv2.filter2D(image, -1, edge_kernel)

# Display
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.title("Original")

plt.subplot(1, 3, 2)
plt.imshow(blurred, cmap='gray')
plt.title("Low-pass Filter (Blur)")

plt.subplot(1, 3, 3)
plt.imshow(edges, cmap='gray')
plt.title("High-pass Filter (Edges)")

plt.show()
